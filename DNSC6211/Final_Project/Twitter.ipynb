# %%
import tweepy
import numpy as np
import csv
import time
from textblob import TextBlob
import sys
import json
import operator
import pandas as pd
import string
import matplotlib.pyplot as plt

# %%
consumer_key = '0w71nUgG81batFDAdEzUJk8SF'
consumer_secret = 'Y3SsrFZok7fTklQVeqs0Vp0axlvFOIS2eaFAlHwqSg34y1yfF0'
access_token = '31352140-M2PDOy0tAtWNISDGcbRghSwSW2wos8NUjFelhN92l'
access_token_secret = 'uwBJQANRrmqYUVdjDdEFZZaqtaUcEXTJge2WdkEAxgnW0'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
consumer_key = 'praLNifz3yc55umOQOvFo6UbP'
consumer_secret = '8TAS5qaLXdZlCLiizuR1GHjTg86gjevqfw00IXYLzLpJFavx7l'
access_token = '31352140-QbBKN43xjR9OLVgX1XAUNjONgjsx4iGY9gocASelK'
access_token_secret = 'qfRpBhHBlWYhHJBd05ppxYIxABEmJv7KxrUt49iXF0VVT'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
consumer_key = 'D73MLBMXydmEiVntlGyydsBPr'
consumer_secret = 'pwSnmxeb9ejLeFG0LmBhlluHu7YRRcvdRiuO3C6XJWi6PhCEQ5'
access_token = '31352140-KANqsyv0iTlh238ueTyZmT82FOQzeQjvRr2txkk7F'
access_token_secret = '2hIJ7vea65NKbEDsOVlYdNNpAFxXWub3KqnswoA3qluCW'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
consumer_key = 'YZENpVzLaTAyaG1ICffF1r7dR'
consumer_secret = 'nviXYIgiRobE0TKB9ubXXZhbLcplRS2b49HFB1uubZts48xLcr'
access_token = '31352140-a5iu0fPpMbRUMk9lLbIBfghPuMYLrjquo469Ryuyu'
access_token_secret = 'sMctB2m6h24c1xJsosJUoq7Kp9Mp5dBgJ4B9Uj3wPUBYQ'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
consumer_key = 'QqeBDozv7HXqqFdIa8NBpT6KM'
consumer_secret = '8sMCvY0Juosdz1QeGWj4SJQsRCBFs6kvUlO5wizXjCSCLgqX1s'
access_token = '801234198-0pYuyE6O1xVjFpj0lnMhWpjucp9vAPdGXcSJbXX5'
access_token_secret = '6FwkyfaEws4woHYqc4nhPC3EO4ANc6jxv2LBC96BxlJ7d'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
def getTwitterData(geocode):
    tweets = []
    for tweet in tweepy.Cursor(api.search,
                           q = "brunch",
                           geocode=geocode,
                           lang="en").items():
        tweets.append(tweet.text)
    
    # make everything lower case   
    lowered_texts = []
    for texts in tweets:
        try: 
            mytext = str(texts.lower())
            lowered_texts.append(mytext)
        except:
            pass
        
    #remove punctuations    
    punctuation = "!\"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~"
    s_sans_punct = ""
    for letter in str(lowered_texts):
        if (letter not in punctuation) and (letter in "abcdefghijklmnopqrstuvwxyz "):
            s_sans_punct += letter
    
    #use textblob do do sentiment analysis
    sentiment = []
    t = TextBlob(s_sans_punct)
    sentiment.append(t.sentiment.polarity)
    
    sentiment2 = []
    score=(sentiment[0])*5
    sentiment2.append(score)
    
    text = []
    text.append(s_sans_punct)
    
    df = pd.DataFrame()
    df['sentiment'] = sentiment2
 
    
    return sentiment2

# %%
#FOUNDING FARMERS 
getTwitterData("38.9003,-77.0446,1km / 10 ")
# Out:
# [1.5909090909090908]

# %%
#getTwitterData("38.903689,-77.044226,1km / 10 ")
getTwitterData("38.806108,-77.054349,1km / 10 ")
# Out:
# [0.0]

# %%
brunch = "/home/lingyao/Desktop/DNSC6211/Final_Project/brunch.csv"
df = pd.read_csv(brunch)
df.dropna()
df["geocode"] = df["Latitude"].map(str) + "," + df["Longitude"].map(str) + "," + "1km / 10"
df
# Out:
#                         name                     street            city state  \
# 0              A Baked Joint                440 K St NW      Washington    DC
# 1              Wicked Waffle               1712 I St NW      Washington    DC
# 2                    Moxie’s            1020 19th St NW      Washington    DC
# 3        Founding Farmers DC   1924 Pennsylvania Ave NW      Washington    DC
# 4             Ted’s Bulletin              505 8th St SE      Washington    DC
# 5                  Highlands            4706 14th St NW      Washington    DC
# 6      Tabard Inn Restaurant               1739 N St NW      Washington    DC
# 7           Old Ebbitt Grill             675 15th St NW      Washington    DC
# 8          Busboys and Poets            2021 14th St NW      Washington    DC
# 9           Tony’s Breakfast               1387 H St NE      Washington    DC
# 10           City Place Cafe            1101 17th St NW      Washington    DC
# ...

# %%
df['geocode'][0:100] = df['geocode'][0:100].apply(getTwitterData)
#df
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['geocode'][100:200] = df['geocode'][100:200].apply(getTwitterData)
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][200:300] = df['geocode'][200:300].apply(getTwitterData)
df.to_csv("0_300.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][300:400] = df['geocode'][300:400].apply(getTwitterData)
df.to_csv("0_400.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][400:500] = df['geocode'][400:500].apply(getTwitterData)
df.to_csv("0_500.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#                         name                     street            city state  \
# 0              A Baked Joint                440 K St NW      Washington    DC
# 1              Wicked Waffle               1712 I St NW      Washington    DC
# 2                    Moxie’s            1020 19th St NW      Washington    DC
# 3        Founding Farmers DC   1924 Pennsylvania Ave NW      Washington    DC
# 4             Ted’s Bulletin              505 8th St SE      Washington    DC
# 5                  Highlands            4706 14th St NW      Washington    DC
# 6      Tabard Inn Restaurant               1739 N St NW      Washington    DC
# 7           Old Ebbitt Grill             675 15th St NW      Washington    DC
# 8          Busboys and Poets            2021 14th St NW      Washington    DC
# 9           Tony’s Breakfast               1387 H St NE      Washington    DC
# 10           City Place Cafe            1101 17th St NW      Washington    DC
# ...

# %%
df['geocode'][500:600] = df['geocode'][500:600].apply(getTwitterData)
df.to_csv("0_600.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][600:700] = df['geocode'][600:700].apply(getTwitterData)
#df
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][700:800] = df['geocode'][700:800].apply(getTwitterData)
df.to_csv("0_800.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][800:900] = df['geocode'][800:900].apply(getTwitterData)
df.to_csv("0_900.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['geocode'][900:1000] = df['geocode'][900:1000].apply(getTwitterData)
df.to_csv("0_1000.csv")
# Out:
# /home/lingyao/.local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# import data from saved .csv file

# %%
fileinput = "/home/lingyao/Desktop/DNSC6211/Final_Project/0_1000.csv"
df = pd.read_csv(fileinput)

# %%
df
# Out:
#      Unnamed: 0                     name                     street  \
# 0             0            A Baked Joint                440 K St NW
# 1             1            Wicked Waffle               1712 I St NW
# 2             2                  Moxie’s            1020 19th St NW
# 3             3      Founding Farmers DC   1924 Pennsylvania Ave NW
# 4             4           Ted’s Bulletin              505 8th St SE
# 5             5                Highlands            4706 14th St NW
# 6             6    Tabard Inn Restaurant               1739 N St NW
# 7             7         Old Ebbitt Grill             675 15th St NW
# 8             8        Busboys and Poets            2021 14th St NW
# 9             9         Tony’s Breakfast               1387 H St NE
# 10           10          City Place Cafe            1101 17th St NW
# 11           11                   Barrel    613 Pennsylvania Ave SE
# 12           12   Farmers Fishers Bakers               3000 K St NW
# ...

# %%
df["twitter_sentiment"] = df["geocode"]
df.drop("geocode",axis=1, inplace=True)
df.drop("Street",axis=1, inplace=True)
df.drop("City",axis=1, inplace=True)
df.drop("State",axis=1, inplace=True)
df.drop("Zip",axis=1, inplace=True)
df.drop("Accuracy Score",axis=1, inplace=True)
df.drop("Number",axis=1, inplace=True)
df.drop("Accuracy Type",axis=1, inplace=True)
df.drop("Unnamed: 0",axis=1, inplace=True)
df
# Out:
#                         name                     street            city state  \
# 0              A Baked Joint                440 K St NW      Washington    DC
# 1              Wicked Waffle               1712 I St NW      Washington    DC
# 2                    Moxie’s            1020 19th St NW      Washington    DC
# 3        Founding Farmers DC   1924 Pennsylvania Ave NW      Washington    DC
# 4             Ted’s Bulletin              505 8th St SE      Washington    DC
# 5                  Highlands            4706 14th St NW      Washington    DC
# 6      Tabard Inn Restaurant               1739 N St NW      Washington    DC
# 7           Old Ebbitt Grill             675 15th St NW      Washington    DC
# 8          Busboys and Poets            2021 14th St NW      Washington    DC
# 9           Tony’s Breakfast               1387 H St NE      Washington    DC
# 10           City Place Cafe            1101 17th St NW      Washington    DC
# ...

# %% [markdown]
# save the cleaned csv file

# %%
df.to_csv("brunch_cleaned.csv")

# %%
fileinput = "/home/lingyao/Desktop/DNSC6211/Final_Project/brunch_cleaned.csv"
df = pd.read_csv(fileinput)

# %%
df
# Out:
#      Unnamed: 0                     name                     street  \
# 0             0            A Baked Joint                440 K St NW
# 1             1            Wicked Waffle               1712 I St NW
# 2             2                  Moxie’s            1020 19th St NW
# 3             3      Founding Farmers DC   1924 Pennsylvania Ave NW
# 4             4           Ted’s Bulletin              505 8th St SE
# 5             5                Highlands            4706 14th St NW
# 6             6    Tabard Inn Restaurant               1739 N St NW
# 7             7         Old Ebbitt Grill             675 15th St NW
# 8             8        Busboys and Poets            2021 14th St NW
# 9             9         Tony’s Breakfast               1387 H St NE
# 10           10          City Place Cafe            1101 17th St NW
# 11           11                   Barrel    613 Pennsylvania Ave SE
# 12           12   Farmers Fishers Bakers               3000 K St NW
# ...

# %%
df_1 = df[df['twitter_sentiment'] == "[1.5909090909090908]"]
df_1
# Out:
#      Unnamed: 0                             name                     street  \
# 1             1                    Wicked Waffle               1712 I St NW
# 2             2                          Moxie’s            1020 19th St NW
# 3             3              Founding Farmers DC   1924 Pennsylvania Ave NW
# 6             6            Tabard Inn Restaurant               1739 N St NW
# 7             7                 Old Ebbitt Grill             675 15th St NW
# 10           10                  City Place Cafe            1101 17th St NW
# 18           18                 Nerds & Nibblers               1451 L St NW
# 20           20                   Birch & Barley            1337 14th St NW
# 22           22                     Sunrise Cafe            1102 17th St NW
# 25           25                         Creperie       1111 New York Ave NW
# 35           35                       Cafe Carvy            1020 19th St NW
# ...

# %%
df_l.to_csv("cared.brunch.csv")
